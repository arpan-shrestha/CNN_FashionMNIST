# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Conv2D, Flatten
from keras import Sequential
from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt

fashion_mnist = keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt.imshow(X_train[0])

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', input_shape=(28,28,1)))
model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_74 (Conv2D)          (None, 28, 28, 32)        320
#
#  conv2d_75 (Conv2D)          (None, 28, 28, 32)        9248
#
#  conv2d_76 (Conv2D)          (None, 28, 28, 32)        9248
#
#  flatten_25 (Flatten)        (None, 25088)             0
#
#  dense_50 (Dense)            (None, 128)               3211392
#
#  dense_51 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 3231498 (12.33 MB)
# Trainable params: 3231498 (12.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.5192 - accuracy: 0.8628 - val_loss: 0.3263 - val_accuracy: 0.8801
# Epoch 2/3
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.2429 - accuracy: 0.9115 - val_loss: 0.3006 - val_accuracy: 0.8909
# Epoch 3/3
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.1835 - accuracy: 0.9301 - val_loss: 0.3224 - val_accuracy: 0.8968

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Training and Validation Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3224 - accuracy: 0.8968
# Test Accuracy: 0.90

# %%
from keras.layers import MaxPooling2D

model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3), padding='same', activation='relu', input_shape=(28,28,1) ))
model.add(MaxPooling2D(pool_size=(2,2), strides=1, padding='same'))

model.add(Conv2D(32,kernel_size=(3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=1, padding='same'))

model.add(Conv2D(32,kernel_size=(3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=1, padding='same'))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_77 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_50 (MaxPooli  (None, 28, 28, 32)        0
#  ng2D)
#
#  conv2d_78 (Conv2D)          (None, 28, 28, 32)        9248
#
#  max_pooling2d_51 (MaxPooli  (None, 28, 28, 32)        0
#  ng2D)
#
#  conv2d_79 (Conv2D)          (None, 28, 28, 32)        9248
#
#  max_pooling2d_52 (MaxPooli  (None, 28, 28, 32)        0
#  ng2D)
#
#  flatten_26 (Flatten)        (None, 25088)             0
#
#  dense_52 (Dense)            (None, 128)               3211392
#
#  dense_53 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 3231498 (12.33 MB)
# Trainable params: 3231498 (12.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 44s 23ms/step - loss: 0.8315 - accuracy: 0.8393 - val_loss: 0.3709 - val_accuracy: 0.8641
# Epoch 2/3
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.3009 - accuracy: 0.8888 - val_loss: 0.3304 - val_accuracy: 0.8810
# Epoch 3/3
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.2596 - accuracy: 0.9029 - val_loss: 0.3197 - val_accuracy: 0.8852

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Training and Validation Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3197 - accuracy: 0.8852
# Test Accuracy: 0.89

# %%
from keras.layers import MaxPooling2D
from keras.callbacks import EarlyStopping
from keras.layers import Dropout



model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3), padding='same', activation='relu', input_shape=(28,28,1) ))
model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))

model.add(Conv2D(32,kernel_size=(3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))

model.add(Conv2D(32,kernel_size=(3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(10,activation='softmax'))

model.summary()

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])


history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Training and Validation Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_80 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_53 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  conv2d_81 (Conv2D)          (None, 14, 14, 32)        9248
#
#  max_pooling2d_54 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_82 (Conv2D)          (None, 7, 7, 32)          9248
#
#  max_pooling2d_55 (MaxPooli  (None, 4, 4, 32)          0
#  ng2D)
#
#  flatten_27 (Flatten)        (None, 512)               0
#
#  dense_54 (Dense)            (None, 128)               65664
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_55 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 85770 (335.04 KB)
# Trainable params: 85770 (335.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 17s 8ms/step - loss: 0.6038 - accuracy: 0.8034 - val_loss: 0.3775 - val_accuracy: 0.8608
# Epoch 2/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3677 - accuracy: 0.8660 - val_loss: 0.3415 - val_accuracy: 0.8754
# Epoch 3/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3270 - accuracy: 0.8796 - val_loss: 0.3320 - val_accuracy: 0.8790
# Epoch 4/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2978 - accuracy: 0.8910 - val_loss: 0.3305 - val_accuracy: 0.8872
# Epoch 5/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2866 - accuracy: 0.8949 - val_loss: 0.2972 - val_accuracy: 0.8934
# Epoch 6/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2695 - accuracy: 0.9001 - val_loss: 0.3208 - val_accuracy: 0.8904
# Epoch 7/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2563 - accuracy: 0.9039 - val_loss: 0.2854 - val_accuracy: 0.8984
# Epoch 8/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2451 - accuracy: 0.9099 - val_loss: 0.2842 - val_accuracy: 0.8997
# Epoch 9/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2374 - accuracy: 0.9123 - val_loss: 0.2959 - val_accuracy: 0.8925
# Epoch 10/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2304 - accuracy: 0.9145 - val_loss: 0.2869 - val_accuracy: 0.8991

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2869 - accuracy: 0.8991
# Test Accuracy: 0.90
